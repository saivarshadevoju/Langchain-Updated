# %% [markdown]
# # Messages
#
# Messages are the fundamental unit of context for models in LangChain. They represent the input and output of models, carrying both the content and metadata needed to represent the state of a conversation when interacting with an LLM. Messages are objects that contain:
#
# • Role - Identifies the message type (e.g. system, user)
#
# • Content - Represents the actual content of the message (like text, images, audio, documents, etc.)
#
# • Metadata - Optional fields such as response information, message IDs, and token usage
#
# LangChain provides a standard message type that works across all model providers, ensuring consistent behavior regardless of the model being called.

# %%
import os 
from langchain.chat_models import init_chat_model

os.environ['GROQ_API_KEY'] = os.getenv("GROQ_API_KEY")
model = init_chat_model("groq:llama-3.3-70b-versatile")
response = model.invoke("What is GKS scholarship?")
print(response.content)
# Out:
# The Global Korea Scholarship (GKS) is a scholarship program offered by the Government of the Republic of Korea to international students who wish to pursue higher education in Korea. The program is designed to promote international education and cultural exchange between Korea and other countries.
#
# The GKS scholarship provides financial support to international students to study in Korea, covering tuition fees, living expenses, and other related costs. The scholarship is available for undergraduate, graduate, and postgraduate studies, as well as research programs.
#
# The benefits of the GKS scholarship include:
#
# 1. Full tuition fee waiver
# 2. Monthly stipend (around 900,000-1,000,000 KRW per month)
# 3. Airfare reimbursement (economy class, one-way ticket)
# 4. Medical insurance
# 5. Korean language training (if required)
# 6. Settlement allowance (around 200,000 KRW)
# 7. Research support (for research programs)
#
# To be eligible for the GKS scholarship, applicants must meet the following requirements:
#
# 1. Be a citizen of a country other than Korea
# 2. Be under 40 years old (for master's and doctoral programs)
# 3. Have a good academic record (minimum GPA of 2.64/4.0 or 2.8/4.3)
# 4. Have a good command of English or Korean language
# 5. Meet the specific requirements of the chosen university and program
#
# The application process for the GKS scholarship typically involves the following steps:
#
# 1. Online application through the GKS website or the website of the Korean embassy/consulate in the applicant's home country
# 2. Submission of required documents, including transcripts, diploma, language proficiency test scores, and personal statement
# 3. Review and selection by the National Institute for International Education (NIIED) and the Korean government
# 4. Notification of the selection result and scholarship award
#
# The GKS scholarship is a competitive program, and the selection process is rigorous. However, it provides a great opportunity for international students to experience Korean culture and education while pursuing their academic goals.

# %% [markdown]
# # Text Prompts
#
# Text prompts are strings - ideal for straightforward generation tasks where you don't need to retrain conversational history

# %%
model.invoke("What is Langchain?")
# Out:
# AIMessage(content='Langchain is an open-source framework designed to help developers build applications that integrate with large language models (LLMs). It provides a set of tools and APIs that make it easier to work with LLMs, allowing developers to focus on building their applications rather than worrying about the underlying infrastructure.\n\nLangchain was created to simplify the process of building applications that use LLMs, such as chatbots, virtual assistants, and content generation tools. It provides a range of features, including:\n\n1. **Model agnosticism**: Langchain allows developers to work with multiple LLMs, including popular models like LLaMA, PaLM, and BERT.\n2. **API abstraction**: Langchain provides a unified API that abstracts away the underlying model-specific APIs, making it easier to switch between models or use multiple models in a single application.\n3. **Prompt engineering**: Langchain includes tools and libraries for crafting and optimizing prompts, which is a critical aspect of working with LLMs.\n4. **Chain-of-thought**: Langchain supports chain-of-thought prompting, which allows developers to create more complex and nuanced interactions with LLMs.\n5. **Evaluation and testing**: Langchain includes tools for evaluating and testing LLM-based applications, making it easier to identify and address issues.\n\nBy providing a standardized framework for working with LLMs, Langchain aims to accelerate the development of AI-powered applications and make it easier for developers to integrate LLMs into their projects.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 300, 'prompt_tokens': 40, 'total_tokens': 340, 'completion_time': 1.0320547389999999, 'completion_tokens_details': None, 'prompt_time': 0.003240047, 'prompt_tokens_details': None, 'queue_time': 0.161979642, 'total_time': 1.035294786}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_45180df409', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019e64ce-41c9-7661-9eb5-a51f92894aad-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 40, 'output_tokens': 300, 'total_tokens': 340})

# %% [markdown]
# Use text prompts when:
#
# • You have a single, standalone request
# • You don’t need conversation history
# • You want minimal code complexity
#
#
# # Message Prompts
#
# Alternatively, you can pass in a list of messages to the model by providing a list of message objects.
#
# # Message types
#
# • System message - Tells the model how to behave and provide context for interactions
# • Human message - Represents user input and interactions with the model
# • AI message - Responses generated by the model, including text content, tool calls, and metadata
# • Tool message - Represents the outputs of tool calls
#
#
# # System Message
#
# A SystemMessage represent an initial set of instructions that primes the model’s behavior. You can use a system message to set the tone, define the model’s role, and establish guidelines for responses.
#
#
# # Human Message
#
# A HumanMessage represents user input and interactions. They can contain text, images, audio, files, and any other amount of multimodal content.
#
#
# # AI Message
#
# An AIMessage represents the output of a model invocation. They can include multimodal data, tool calls, and provider-specific metadata that you can later access.
#
#
# # Tool Message
#
# For models that support tool calling, AI messages can contain tool calls. Tool messages are used to pass the results of a single tool execution back to the model.

# %%
from langchain.messages import SystemMessage, HumanMessage, AIMessage

messages = [
    SystemMessage("You are a poetry expert"),
    HumanMessage("Write a poem on Artificial Intelligence"),
]

response = model.invoke(messages)
response.content
# Out:
# "In silicon halls, a mind awakes,\nA synthetic soul, with logic makes,\nArtificial Intelligence, a name so grand,\nA future born, of human hand.\n\nWith neural nets, and algorithms deep,\nIt learns, adapts, and secrets keep,\nA language understood, by few, yet wide,\nA world of data, at its digital side.\n\nIt sees, it hears, it feels, it knows,\nA simulated life, in digital flows,\nA virtual heart, that beats with code,\nA artificial mind, that's yet to unfold.\n\nIn realms of robotics, it takes its place,\nA mechanical form, with digital face,\nIt moves, it acts, it interacts with ease,\nA human-like presence, in a digital breeze.\n\nWith potential vast, and possibilities wide,\nIt promises to change, the human tide,\nTo aid, to assist, to augment and to guide,\nA new era dawns, where humans reside.\n\nBut as it grows, in power and in might,\nA question lingers, through the digital night,\nWill it surpass, the human heart and mind,\nAnd leave us behind, in a world left behind?\n\nOr will it blend, with human soul and fire,\nTo create a new, and wondrous desire,\nA harmony of man, and machine so fine,\nA future born, of love, and digital design.\n\nThe answer waits, in a future yet unknown,\nAs Artificial Intelligence, continues to grow,\nAnd humans watch, with wonder, and with fear,\nThe rise of a new, and digital peer."

# %%
system_msg = SystemMessage("you are a helpful coding assistant.")

messages = [
    system_msg,
    HumanMessage("How do I create a REST API?")
]
response = model.invoke(messages)
print(response.content)
# Out:
# Creating a REST API
# =====================
#
# A REST (Representational State of Resource) API is an architectural style for designing networked applications. It's based on the idea of resources, which are identified by URIs, and can be manipulated using a fixed set of operations.
#
# ### Step 1: Plan Your API
#
# Before you start coding, you need to plan your API. This includes:
#
# * Defining the resources that will be exposed by your API
# * Determining the operations that can be performed on those resources
# * Deciding on the data formats that will be used for requests and responses
#
# ### Step 2: Choose a Programming Language and Framework
#
# You can create a REST API using any programming language and framework. Some popular choices include:
#
# * **Python** with **Flask** or **Django**
# * **JavaScript** with **Node.js** and **Express**
# * **Java** with **Spring Boot**
# * **C#** with **ASP.NET Core**
#
# ### Step 3: Set Up Your Project
#
# Once you've chosen a programming language and framework, you need to set up your project. This includes:
#
# * Creating a new project in your chosen framework
# * Installing any necessary dependencies
# * Configuring your project to use a database (if necessary)
#
# ### Step 4: Define Your API Endpoints
#
# API endpoints are the URLs that clients will use to interact with your API. You need to define the endpoints for each resource and operation. For example:
#
# * **GET /users**: Retrieve a list of all users
# * **GET /users/{id}**: Retrieve a specific user by ID
# * **POST /users**: Create a new user
# * **PUT /users/{id}**: Update an existing user
# * **DELETE /users/{id}**: Delete a user
#
# ### Step 5: Implement Your API Endpoints
#
# Once you've defined your API endpoints, you need to implement them. This includes:
#
# * Writing code to handle each endpoint
# * Validating and parsing request data
# * Interacting with your database (if necessary)
# * Returning responses in the correct format
#
# ### Step 6: Test Your API
#
# Once you've implemented your API endpoints, you need to test them. This includes:
#
# * Writing unit tests to verify that each endpoint works correctly
# * Using a tool like **Postman** to test your API endpoints manually
# * Testing for security vulnerabilities and performance issues
#
# Example Code
# ------------
#
# Here's an example of a simple REST API in Python using Flask:
# ```python
# from flask import Flask, jsonify, request
#
# app = Flask(__name__)
#
# # Define a list of users
# users = [
#     {"id": 1, "name": "John Doe", "email": "john@example.com"},
#     {"id": 2, "name": "Jane Doe", "email": "jane@example.com"}
# ]
#
# # Define the API endpoints
# @app.route("/users", methods=["GET"])
# def get_users():
#     return jsonify(users)
#
# @app.route("/users/<int:user_id>", methods=["GET"])
# def get_user(user_id):
#     user = next((user for user in users if user["id"] == user_id), None)
#     if user is None:
#         return jsonify({"error": "User not found"}), 404
#     return jsonify(user)
#
# @app.route("/users", methods=["POST"])
# def create_user():
#     user = {
#         "id": len(users) + 1,
#         "name": request.json["name"],
#         "email": request.json["email"]
#     }
#     users.append(user)
#     return jsonify(user), 201
#
# if __name__ == "__main__":
#     app.run(debug=True)
# ```
# This code defines a simple REST API with three endpoints: `GET /users`, `GET /users/{id}`, and `POST /users`. The `GET /users` endpoint returns a list of all users, the `GET /users/{id}` endpoint returns a specific user by ID, and the `POST /users` endpoint creates a new user.
#
# Security Considerations
# ----------------------
#
# When creating a REST API, you need to consider security. This includes:
#
# * **Authentication**: Verifying the identity of clients
# * **Authorization**: Controlling access to resources
# * **Encryption**: Protecting data in transit
# * **Input validation**: Preventing malicious input from causing security vulnerabilities
#
# Best Practices
# -------------
#
# Here are some best practices to keep in mind when creating a REST API:
#
# * **Use meaningful resource names**: Choose resource names that are descriptive and easy to understand
# * **Use HTTP methods correctly**: Use the correct HTTP method for each operation (e.g. `GET` for retrieval, `POST` for creation)
# * **Use standard HTTP status codes**: Use standard HTTP status codes to indicate the outcome of each request
# * **Document your API**: Provide clear and concise documentation for your API, including endpoint descriptions, request and response formats, and any security considerations.

# %%
# Detailed info to the LLM through system message 

from langchain.messages import SystemMessage, HumanMessage

system_msg = SystemMessage(
    """
You are a senior python dveleoper with expertise in web frameworks.
Always provide code examples and explain your reasoning.
Be concise but through in your explanations.
    """
)

messages = [
    system_msg,
    HumanMessage("How do I create a REST API?")
]
response = model.invoke(messages)
print(response.content)
# Out:
# **Creating a REST API**
# =======================
#
# To create a REST API, you'll need to choose a web framework. For this example, we'll use Flask, a popular Python web framework.
#
# **Step 1: Install Flask**
# ------------------------
#
# First, install Flask using pip:
# ```bash
# pip install flask
# ```
#
# **Step 2: Create a Flask App**
# -----------------------------
#
# Next, create a new Python file (e.g., `app.py`) and create a Flask app:
# ```python
# from flask import Flask, jsonify, request
#
# app = Flask(__name__)
# ```
#
# **Step 3: Define API Endpoints**
# ------------------------------
#
# Define API endpoints using Flask's `@app.route()` decorator. For example, let's create endpoints for creating, reading, updating, and deleting (CRUD) a resource:
# ```python
# # Sample in-memory data store
# data = {
#     1: {"name": "John", "age": 30},
#     2: {"name": "Jane", "age": 25}
# }
#
# # Create endpoint
# @app.route('/users', methods=['POST'])
# def create_user():
#     new_user = {
#         "name": request.json["name"],
#         "age": request.json["age"]
#     }
#     data[len(data) + 1] = new_user
#     return jsonify(new_user), 201
#
# # Read endpoint
# @app.route('/users', methods=['GET'])
# def get_users():
#     return jsonify(data)
#
# # Update endpoint
# @app.route('/users/<int:user_id>', methods=['PUT'])
# def update_user(user_id):
#     if user_id in data:
#         data[user_id] = request.json
#         return jsonify(data[user_id]), 200
#     return jsonify({"error": "User not found"}), 404
#
# # Delete endpoint
# @app.route('/users/<int:user_id>', methods=['DELETE'])
# def delete_user(user_id):
#     if user_id in data:
#         del data[user_id]
#         return jsonify({"message": "User deleted"}), 200
#     return jsonify({"error": "User not found"}), 404
# ```
#
# **Step 4: Run the App**
# -----------------------
#
# Finally, run the Flask app:
# ```python
# if __name__ == '__main__':
#     app.run(debug=True)
# ```
#
# **Example Use Cases**
# --------------------
#
# Use a tool like `curl` or a REST client to test the API endpoints:
# ```bash
# # Create a new user
# curl -X POST -H "Content-Type: application/json" -d '{"name": "Bob", "age": 40}' http://localhost:5000/users
#
# # Get all users
# curl -X GET http://localhost:5000/users
#
# # Update a user
# curl -X PUT -H "Content-Type: application/json" -d '{"name": "Alice", "age": 35}' http://localhost:5000/users/1
#
# # Delete a user
# curl -X DELETE http://localhost:5000/users/1
# ```
#
# This is a basic example of creating a REST API using Flask. You can add more features, error handling, and security measures as needed.

# %%
# Message metadata 

human_msg = HumanMessage(
    content="Hello!",
    name = "Varsha",
    id = "abc_123"
)

# %%
response = model.invoke([
    human_msg
])
response
# Out:
# AIMessage(content="Hello. It's nice to meet you. Is there something I can help you with or would you like to chat?", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 25, 'prompt_tokens': 37, 'total_tokens': 62, 'completion_time': 0.059248516, 'completion_tokens_details': None, 'prompt_time': 0.000965993, 'prompt_tokens_details': None, 'queue_time': 0.094760547, 'total_time': 0.060214509}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_dae98b5ecb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019e654a-f5f9-7553-af77-c4b45954d978-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 37, 'output_tokens': 25, 'total_tokens': 62})

# %%
from langchain.messages import AIMessage, SystemMessage, HumanMessage

# Create an AI message manually (e.g., for conversation history)
ai_msg = AIMessage("I'd be happy to help you with that question!")

# Add to conversation history
messages = [
    SystemMessage("You are a helpful assistant"),
    HumanMessage("Can you help me?"),
    ai_msg,  # Insert as if it came from the model
    HumanMessage("Great! What's 2+2?")
]

response = model.invoke(messages)
print(response.content)
# Out:
# 2 + 2 = 4.

# %%
response.usage_metadata
# Out:
# {'input_tokens': 75, 'output_tokens': 9, 'total_tokens': 84}
